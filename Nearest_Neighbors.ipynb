# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
from keras.datasets import cifar10
plt.rcParams['figure.figsize'] = (10.0, 8.0)
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# classifier take some image from test set and compares with every image from train set .

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %%
print('Trainig data shape : ', X_train.shape)
print('Trainig abels shape : ', y_train.shape)
print('Test data shape : ', X_test.shape)
print('Test labels shape : ', y_test.shape)
# Out:
# Trainig data shape :  (50000, 32, 32, 3)
# Trainig abels shape :  (50000, 1)
# Test data shape :  (10000, 32, 32, 3)
# Test labels shape :  (10000, 1)

# %%
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

num_classes = len(classes)
samples_per_class = 7  # 7 images per class
for y, cls in enumerate(classes):
    indxs = np.flatnonzero(y_train==y)
    indxs = np.random.choice(indxs, samples_per_class, replace=False)
    for i, idx in enumerate(indxs):
        plt_idx = i*num_classes+y+1
        plt.subplot(samples_per_class, num_classes, plt_idx)
        plt.imshow(X_train[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls)
plt.show()

# %%
num_training = 5000
indx = range(num_training)
X_train = X_train[indx].astype('float')
y_train = y_train[indx].astype('int')

num_test = 500
indx = range(num_test)
X_test = X_test[indx].astype('float')
y_test = y_test[indx].astype('int')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-31183579045f> in <module>
#       6 num_test = 500
#       7 indx = range(num_test)
# ----> 8 X_test = X_test[indx].astype('int')
#       9 y_test = y_test[indx].astype('int')
#
# TypeError: tuple indices must be integers or slices, not range

# %%
X_train = np.reshape(X_train, (X_train.shape[0], -1))
X_test = np.reshape = (X_test, (X_test.shape[0], -1))
print(X_train.shape, X_test.shape)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-b2680993787d> in <module>
# ----> 1 X_train = np.reshape(X_train, (X_train.shape[0], -1))
#       2 X_test = np.reshape = (X_test, (X_test.shape[0], -1))
#       3 print(X_train.shape, X_test.shape)
#
# TypeError: 'tuple' object is not callable
